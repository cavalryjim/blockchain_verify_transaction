# %% [markdown]
# # Blockchain: Verify a Transaction

# %% [markdown]
# You can find an explanation of the code in [this article](https://blog.agilephd.com/posts/blockchain_verify_tx/)

# %% [markdown]
# Depending on your development environment, you may have to install the eth-account package.
#
# `$ pip install eth-account`
#
# Or you can install all the required packages from the `requirements.txt` file.
#
# `$ pip install -r requirements.txt`

# %%
from eth_account import Account

# %%
acct = Account.create()
private_key = acct.key
wallet_address = acct.address

# %%
tx = {
    "nonce": 0,
    "gasPrice": 1_000_000_000,
    "gas": 21000,
    "to": "0x0000000000000000000000000000000000001a9f",
    "value": 200
}

# %%
signed_tx = Account.sign_transaction(tx, private_key)

# %%
confirm_address = Account.recover_transaction(
    signed_tx.raw_transaction
)

# %%
print("wallet address:", wallet_address)
print("address recovered from the tx:", confirm_address)
print("valid:", wallet_address.lower() == confirm_address.lower())
# Out:
# wallet address: 0x8Db4712fF1944a0F6E8925cA9aE953E037900809
# address recovered from the tx: 0x8Db4712fF1944a0F6E8925cA9aE953E037900809
# valid: True
